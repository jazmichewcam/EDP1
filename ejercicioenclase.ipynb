# %%
from sympy import *#libreria

# %% [markdown]
# Libreria para hacer calculos simbolicos. Permite hacer operaciones analiticas

# %%
x=symbols('x')# x como variable

# %% [markdown]
# Utilizamos la variable x como simbolo

# %%
x**2+5
# Out:
# x**2 + 5

# %%
c1=plotting.plot(x*x)#Grafica de x2

# %% [markdown]
# Traza la grafica y=x2

# %%
cl=plotting.plot(x*x,show=False)
c2=plotting.plot(x**3,show=False)

# %% [markdown]
# show=false permite no mostrar las graficas momentaneamente por si se requiere modificar algun dato

# %%
c1 #Indica qué es y en qué espacio de memoria está

# %%
c1.append(c2[0]) #Anida las gráficas sin los ejes

# %% [markdown]
# Agregar datos extras al final

# %%
c1

# %%
c1.show() # Grafica de la primera funcion

# %% [markdown]
# muestra todas las figuras

# %%
c1.extend(c2)

# %% [markdown]
# Agrega mas de un elemento al final

# %%
c1.show()

# %% [markdown]
# muestra todas las figuras

# %%
c2.show()# grafica la segunda funcion

# %% [markdown]
# muestra todas las figuras

# %%
from sympy.plotting import plot

# %% [markdown]
# Es una forma importar la funcion plot de la biblioteca sympy que permite graficar expresiones analiticas

# %%
plot(x**2)#grafica de x2

# %%
plot(x**2,(x,-1,1))# Grafica de la funcion

# %% [markdown]
# Grafica la funcion pero especifica las dimensiones en el eje x

# %%
plot(exp(x))
#plot(exp(x),(x,0,2))

# %% [markdown]
# Grafica la funcion pero especifica las dimensiones en el eje x

# %%
plot(x,x**2,x**3, (x,-2,2))

# %% [markdown]
# Grafica la funcion pero especifica las dimensiones en el eje x

# %%
plot(x**2,adaptative=False,nb_of_points=10) #Revisar

# %% [markdown]
# Desactiva la adaptacion automatica de la cantidad de puntos usados para dibujar la grafica

# %% [markdown]
# ### Curvas parametrizadas

# %%
from sympy import plot_parametric #libreria sympy

# %% [markdown]
# graficar curvas paramétricas en un plano 2D

# %%
s=symbols('s')# variable simbolica

# %% [markdown]
# El nombre de la variable simbólica que se va a crear.

# %%
plot_parametric((cos(s)),sin(s))# Grafica la funcion

# %%
plot_parametric((cos(s),sin(s)),(s,s**2),(s,-4,4))

# %%
c2[0].line_color='green'

# %%
c2.show()

# %% [markdown]
# ### Graficas 3D

# %%
from sympy.plotting import plot3d

# %%
x,y=symbols('x y')

# %%
plot3d(x*y)

# %%
plot3d(x*y, (x,-5,5),(y,-5,5))

# %%
plot3d(x*y, -x*y, (x,-5,5),(y,-5,5))

# %%
plot3d((x**2 + y**2, (x,-5,5),(y,-5,5)),(x*y,(x,-3,3),(y,-3,3)))

# %%
from sympy.plotting import plot3d_parametric_line

# %%
plot3d_parametric_line(cos(s),sin(s),s)

# %%
plot3d_parametric_line((cos(s),sin(s),s,(s,-5,5)),(sin(s),s**2,s,(s,-5,5)))

# %%
from sympy.plotting import plot3d_parametric_surface

# %%
u, v =symbols('u v')

# %%
plot3d_parametric_surface(cos(u+v),sin(u-v),u-v)

# %%
plot3d_parametric_surface(cos(v)*cos(u),cos(v)*sin(u),sin(v))

# %% [markdown]
# Funciones implícitas

# %%
from sympy import plot_implicit, symbols, Eq, And

# %%
x, y = symbols(' x y')

# %%
p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
p6 = plot_implicit(y > x**2)

# %%
p6 = plot_implicit(And(y > x, y > -x))

# %%
from sympy.plotting import plot3d

# %%
from sympy import symbols

# %%
x, y = symbols(' x y')

# %%
plot3d(x**3-x*y+y**3)
